0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool>

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(44/6433)*100
# Out:
# 0.6839732628633608

# %%
(df.isnull().sum()/6433)
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.006840
# pickup_zone        0.004042
# dropoff_zone       0.006995
# pickup_borough     0.004042
# dropoff_borough    0.006995
# dtype: float64

# %%
(df.isnull().sum()/6433)*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
#missing data handling
#1) Imputaion (fill in the blanks)
 #   1)statistical measures
  #  2)parameter
#2)delete data
 #   rows
  #  columns

# %%
df.drop('pickup_zone',axis=1)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop('pickup',axis=1,inplace=True)
df
# Out:
#                   dropoff  passengers  distance  fare   tip  tolls  total  \
# 0     2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0  12.95
# 1     2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30
# 2     2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0  14.16
# 3     2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0  36.95
# 4     2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40
# ...                   ...         ...       ...   ...   ...    ...    ...
# 6428  2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0   6.36
# 6429  2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0  58.80
# 6430  2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0  17.30
# 6431  2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0   6.80
# 6432  2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0  20.16
#
#        color      payment                      dropoff_zone pickup_borough  \
# ...

# %%
df.columns
# Out:
# Index(['dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls', 'total',
#        'color', 'payment', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough'],
#       dtype='object')

# %%
df.drop(['dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls'],axis=1,inplace=True)
df
#if you keep pickup=true it throws error as it is already deleted
# Out:
#       total   color      payment                      dropoff_zone  \
# 0     12.95  yellow  credit card               UN/Turtle Bay South
# 1      9.30  yellow         cash             Upper West Side South
# 2     14.16  yellow  credit card                      West Village
# 3     36.95  yellow  credit card                    Yorkville West
# 4     13.40  yellow  credit card                    Yorkville West
# ...     ...     ...          ...                               ...
# 6428   6.36   green  credit card              Central Harlem North
# 6429  58.80   green  credit card  East Concourse/Concourse Village
# 6430  17.30   green         cash                    Bushwick North
# 6431   6.80   green  credit card      East Flatbush/Remsen Village
# 6432  20.16   green  credit card                   Windsor Terrace
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 2         Manhattan       Manhattan
# ...

# %%
df.drop([2,3,6430,6432],axis=0,inplace=True)

# %%
df
# Out:
#       total   color      payment                      dropoff_zone  \
# 0     12.95  yellow  credit card               UN/Turtle Bay South
# 1      9.30  yellow         cash             Upper West Side South
# 4     13.40  yellow  credit card                    Yorkville West
# 5     12.96  yellow  credit card                      Midtown East
# 6     18.80  yellow  credit card           Two Bridges/Seward Park
# ...     ...     ...          ...                               ...
# 6426   5.80   green  credit card             Upper West Side North
# 6427  20.00   green         cash                 East Harlem South
# 6428   6.36   green  credit card              Central Harlem North
# 6429  58.80   green  credit card  East Concourse/Concourse Village
# 6431   6.80   green  credit card      East Flatbush/Remsen Village
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 4         Manhattan       Manhattan
# ...

# %%
df.reset_index()
# Out:
#       index  total   color      payment                      dropoff_zone  \
# 0         0  12.95  yellow  credit card               UN/Turtle Bay South
# 1         1   9.30  yellow         cash             Upper West Side South
# 2         4  13.40  yellow  credit card                    Yorkville West
# 3         5  12.96  yellow  credit card                      Midtown East
# 4         6  18.80  yellow  credit card           Two Bridges/Seward Park
# ...     ...    ...     ...          ...                               ...
# 6424   6426   5.80   green  credit card             Upper West Side North
# 6425   6427  20.00   green         cash                 East Harlem South
# 6426   6428   6.36   green  credit card              Central Harlem North
# 6427   6429  58.80   green  credit card  East Concourse/Concourse Village
# 6428   6431   6.80   green  credit card      East Flatbush/Remsen Village
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# ...

# %%
df.reset_index(drop=True)
#its mandatory to apply reset index after deleting rows from dataframe
# Out:
#       total   color      payment                      dropoff_zone  \
# 0     12.95  yellow  credit card               UN/Turtle Bay South
# 1      9.30  yellow         cash             Upper West Side South
# 2     13.40  yellow  credit card                    Yorkville West
# 3     12.96  yellow  credit card                      Midtown East
# 4     18.80  yellow  credit card           Two Bridges/Seward Park
# ...     ...     ...          ...                               ...
# 6424   5.80   green  credit card             Upper West Side North
# 6425  20.00   green         cash                 East Harlem South
# 6426   6.36   green  credit card              Central Harlem North
# 6427  58.80   green  credit card  East Concourse/Concourse Village
# 6428   6.80   green  credit card      East Flatbush/Remsen Village
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 2         Manhattan       Manhattan
# ...

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       total   color      payment                      dropoff_zone  \
# 0     12.95  yellow  credit card               UN/Turtle Bay South
# 1      9.30  yellow         cash             Upper West Side South
# 2     13.40  yellow  credit card                    Yorkville West
# 3     12.96  yellow  credit card                      Midtown East
# 4     18.80  yellow  credit card           Two Bridges/Seward Park
# ...     ...     ...          ...                               ...
# 6424   5.80   green  credit card             Upper West Side North
# 6425  20.00   green         cash                 East Harlem South
# 6426   6.36   green  credit card              Central Harlem North
# 6427  58.80   green  credit card  East Concourse/Concourse Village
# 6428   6.80   green  credit card      East Flatbush/Remsen Village
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 2         Manhattan       Manhattan
# ...

# %%
df[df['color']=='yellow']
# Out:
#       total   color      payment                  dropoff_zone pickup_borough  \
# 0     12.95  yellow  credit card           UN/Turtle Bay South      Manhattan
# 1      9.30  yellow         cash         Upper West Side South      Manhattan
# 2     13.40  yellow  credit card                Yorkville West      Manhattan
# 3     12.96  yellow  credit card                  Midtown East      Manhattan
# 4     18.80  yellow  credit card       Two Bridges/Seward Park      Manhattan
# ...     ...     ...          ...                           ...            ...
# 5444  15.96  yellow  credit card      Financial District North      Manhattan
# 5445  14.16  yellow  credit card         Upper East Side North      Manhattan
# 5446  15.36  yellow  credit card         Upper West Side South      Manhattan
# 5447  14.16  yellow  credit card  Penn Station/Madison Sq West      Manhattan
# 5448  14.63  yellow  credit card         Upper West Side North      Manhattan
#
#      dropoff_borough
# ...

# %%
df[df['total']>15]
# Out:
#       total   color      payment                      dropoff_zone  \
# 4     18.80  yellow  credit card           Two Bridges/Seward Park
# 6     19.30  yellow  credit card                    Midtown Center
# 8     17.80  yellow         cash                           Astoria
# 13    16.80  yellow         cash                      Clinton East
# 14    16.30  yellow         cash     Meatpacking/West Village West
# ...     ...     ...          ...                               ...
# 6420  17.30   green         cash        Spuyten Duyvil/Kingsbridge
# 6421  19.30   green  credit card                 Hillcrest/Pomonok
# 6423  26.82   green  credit card                     East New York
# 6425  20.00   green         cash                 East Harlem South
# 6427  58.80   green  credit card  East Concourse/Concourse Village
#
#      pickup_borough dropoff_borough
# 4         Manhattan       Manhattan
# 6         Manhattan       Manhattan
# 8            Queens          Queens
# ...

# %%
total15=df[df['total']>15]
total15
# Out:
#       total   color      payment                      dropoff_zone  \
# 4     18.80  yellow  credit card           Two Bridges/Seward Park
# 6     19.30  yellow  credit card                    Midtown Center
# 8     17.80  yellow         cash                           Astoria
# 13    16.80  yellow         cash                      Clinton East
# 14    16.30  yellow         cash     Meatpacking/West Village West
# ...     ...     ...          ...                               ...
# 6420  17.30   green         cash        Spuyten Duyvil/Kingsbridge
# 6421  19.30   green  credit card                 Hillcrest/Pomonok
# 6423  26.82   green  credit card                     East New York
# 6425  20.00   green         cash                 East Harlem South
# 6427  58.80   green  credit card  East Concourse/Concourse Village
#
#      pickup_borough dropoff_borough
# 4         Manhattan       Manhattan
# 6         Manhattan       Manhattan
# 8            Queens          Queens
# ...

# %%
df[(df['payment']=='cash')(df['total']>20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-1f26b7567f4a> in <module>
# ----> 1 df[(df['payment']=='cash')(df['total']>20)]
#
# TypeError: 'Series' object is not callable
